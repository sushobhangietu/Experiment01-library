# %%
import pandas as pd
import numpy as np

# %%
l1=list(eval(input("enter dataset")))
series=pd.Series(l1)

mean=series.mean()
print("mean: ",mean)

median=series.median()
print("median: ",median)

mode=series.mode()
print("mode: ",mode)
# Out:
# enter dataset10,20,30,40
# mean:  25.0
# median:  25.0
# mode:  0    10
# 1    20
# 2    30
# 3    40
# dtype: int64
